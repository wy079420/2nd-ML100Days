# %% [markdown]
# ## 作業一
# #### 我找的資料來自於kaggle competition中的Santander Customer Transaction Prediction，
# #### 這筆資料要處理的問題主要是判斷說資料中的哪位顧客會進行交易。
# 1）這資料的主要重要性在於它是企業的核心問題，因為我可以通過資料去建立一個模型去預測未來哪一個顧客將於再次進行交易。<br>
# 2）此資料來自於kaggle上，他的提供者是一個名為Santander的銀行，他們對於顧客的財政狀況是感興趣的。<br>
# 3）此資料的資料型態為結構性資料，由一系列的表格建構而成。<br>
# 4）在比賽中，其判斷模型的好壞指標為AUC(Area under curve)

# %% [markdown]
# ## 作業二
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1) 這個問題的核心在於我們希望提高車隊的載客量。<br>
# 2) 資料由車隊的行駛紀錄建構成，我們可以通過行駛記錄知道在不同時段是客戶在特定地區的分佈，<br>
#       我們可以通過分析這些資料知道司機應該在時間去什麼地方。<br>
# 3) 收集得來的資料是結構式資料。<br>
# 4) 以星期或月為單位，確認車隊業績是否有提升，沒提升問題又在何處，並針對其去解決。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    
    n = len(y)
    
    MSE = (1.0/n)*np.sum((y-y_hat)**2)
    
    return MSE

def mean_absolute_error(y,y_hat):
    
    n = len(y)
    
    MSE = (1.0/n)*np.sum(np.absolute(y-y_hat))
    
    return MSE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 322.808
# The Mean absolute error is 14.137
